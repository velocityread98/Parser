# %%
# !git clone https://github.com/ByteDance/Dolphin.git
# Out:
# Cloning into 'Dolphin'...
# remote: Enumerating objects: 197, done.
# remote: Counting objects: 100% (95/95), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 197 (delta 74), reused 33 (delta 33), pack-reused 102 (from 2)
# Receiving objects: 100% (197/197), 11.21 MiB | 15.09 MiB/s, done.
# Resolving deltas: 100% (90/90), done.

# %%
cd Dolphin/
# Out:
# /content/Dolphin

# %%
pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (0.35.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.1.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2025.8.3)

# %%
# !huggingface-cli download ByteDance/Dolphin --local-dir ./hf_model
# Out:
# ⚠️  Warning: 'huggingface-cli download' is deprecated. Use 'hf download' instead.
# Fetching 9 files:   0% 0/9 [00:00<?, ?it/s]Downloading '.gitattributes' to 'hf_model/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.a6344aac8c09253b3b630fb776ae94478aa0275b.incomplete'
#
# .gitattributes: 1.52kB [00:00, 7.50MB/s]
# Download complete. Moving file to hf_model/.gitattributes
# Fetching 9 files:  11% 1/9 [00:00<00:02,  3.34it/s]Downloading 'config.json' to 'hf_model/.cache/huggingface/download/8_PA_wEVGiVa2goH2H4KQOQpvVY=.b36c7a3288f4d28b7ad1c510231be6150ee0c1d3.incomplete'
# Downloading 'tokenizer.json' to 'hf_model/.cache/huggingface/download/HgM_lKo9sdSCfRtVg7MMFS7EKqo=.fa3c9625a4133ccea935d1a1b786bd375db3ee11.incomplete'
# Downloading 'special_tokens_map.json' to 'hf_model/.cache/huggingface/download/ahkChHUJFxEmOdq5GDFEmerRzCY=.f17762fa69353b2b891f72edeb9e3329077eae6b.incomplete'
# Downloading 'model.safetensors' to 'hf_model/.cache/huggingface/download/xGOKKLRSlIhH692hSVvI1-gpoa8=.0374fcfc30395cbb321c916535c8b3d66046921f57c3453c4bc6887803d8509a.incomplete'
# Downloading 'generation_config.json' to 'hf_model/.cache/huggingface/download/3EVKVggOldJcKSsGjSdoUCN1AyQ=.a1ea592445949d20f8e809171faa29d4cdb54dde.incomplete'
# Downloading 'README.md' to 'hf_model/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.0a239101345021ac3a9d09de84a2e0dbf9b86831.incomplete'
#
# config.json: 0.00B [00:00, ?B/s]
#
# tokenizer.json: 0.00B [00:00, ?B/s]Downloading 'preprocessor_config.json' to 'hf_model/.cache/huggingface/download/PYH5dHjks7Ei0Yd3X0Z8xIwsCNQ=.6247e7f97aa2383d3c4cba7fb3c116e1b6ce6fb5.incomplete'
# config.json: 4.85kB [00:00, 2.11MB/s]
#
#
#
# special_tokens_map.json:   0% 0.00/277 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]Download complete. Moving file to hf_model/config.json
# special_tokens_map.json: 100% 277/277 [00:00<00:00, 169kB/s]
# README.md: 3.51kB [00:00, 77.9kB/s]
# Download complete. Moving file to hf_model/special_tokens_map.json
#
# Download complete. Moving file to hf_model/README.md
# Fetching 9 files:  22% 2/9 [00:00<00:01,  5.10it/s]
#
#
# preprocessor_config.json: 100% 477/477 [00:00<00:00, 369kB/s]
# generation_config.json: 100% 160/160 [00:00<00:00, 510kB/s]
# Download complete. Moving file to hf_model/preprocessor_config.json
# Download complete. Moving file to hf_model/generation_config.json
#
#
# tokenizer.json: 7.86MB [00:00, 57.1MB/s]
# Download complete. Moving file to hf_model/tokenizer.json
# Downloading 'tokenizer_config.json' to 'hf_model/.cache/huggingface/download/vzaExXFZNBay89bvlQv-ZcI6BTg=.df6cf2aded7c75e053ca14aafc90b8d4819b46fd.incomplete'
#
# tokenizer_config.json: 4.05MB [00:00, 119MB/s]
# Download complete. Moving file to hf_model/tokenizer_config.json
#
# model.safetensors:   0% 0.00/796M [00:00<?, ?B/s]
# model.safetensors:   8% 67.1M/796M [00:02<00:31, 23.5MB/s]
# model.safetensors:  17% 134M/796M [00:03<00:13, 48.2MB/s]
# model.safetensors:  22% 175M/796M [00:03<00:09, 66.9MB/s]
# model.safetensors:  39% 309M/796M [00:06<00:09, 49.8MB/s]
# model.safetensors:  58% 460M/796M [00:06<00:03, 88.7MB/s]
# model.safetensors:  66% 528M/796M [00:07<00:02, 101MB/s]
# model.safetensors:  83% 662M/796M [00:08<00:01, 116MB/s]
# model.safetensors: 100% 796M/796M [00:10<00:00, 75.0MB/s]
# Download complete. Moving file to hf_model/model.safetensors
# Fetching 9 files: 100% 9/9 [00:11<00:00,  1.25s/it]
# /content/Dolphin/hf_model

# %%
# !pip install pymupdf
# Out:
# Collecting pymupdf
#   Downloading pymupdf-1.26.4-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.26.4-cp39-abi3-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 72.3 MB/s eta 0:00:00
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.26.4

# %%
# !python demo_page_hf.py --model_path ./hf_model --input_path /content/drive/MyDrive/out2/NLTK.pdf --save_dir /content/drive/MyDrive/out2/
# Out:
# 2025-10-01 01:57:29.960174: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759283849.980835    4969 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759283849.986709    4969 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1759283850.001642    4969 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759283850.001665    4969 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759283850.001669    4969 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1759283850.001674    4969 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-01 01:57:30.006616: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /content/Dolphin/utils/markdown_utils.py:431: SyntaxWarning: invalid escape sequence '\['
#   markdown_content = markdown_content.replace("\[ \\\\", "$$ \\\\")
# /content/Dolphin/utils/markdown_utils.py:434: SyntaxWarning: invalid escape sequence '\]'
#   markdown_content = markdown_content.replace("\\\\ \]", "\\\\ $$")
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
#
# Total files to process: 1
#
# Processing /content/drive/MyDrive/out2/NLTK.pdf
# Successfully converted 504 pages from PDF
# Processing page 1/504
# Processing page 2/504
# Processing page 3/504
# Processing page 4/504
# Processing page 5/504
# Processing page 6/504
# Processing page 7/504
# Processing page 8/504
# Processing page 9/504
# Processing page 10/504
# Processing page 11/504
# Processing page 12/504
# Processing page 13/504
# Processing page 14/504
# Processing page 15/504
# Processing page 16/504
# Processing page 17/504
# Processing page 18/504
# Processing page 19/504
# Processing page 20/504
# Processing page 21/504
# Processing page 22/504
# Processing page 23/504
# Processing page 24/504
# Processing page 25/504
# Processing page 26/504
# Processing page 27/504
# Processing page 28/504
# Processing page 29/504
# Processing page 30/504
# Processing page 31/504
# Processing page 32/504
# Processing page 33/504
# Processing page 34/504
# Processing page 35/504
# Processing page 36/504
# Processing page 37/504
# Processing page 38/504
# Processing page 39/504
# Processing page 40/504
# Processing page 41/504
# Processing page 42/504
# Processing page 43/504
# Processing page 44/504
# Processing page 45/504
# Processing page 46/504
# Processing page 47/504
# Processing page 48/504
# Processing page 49/504
# Processing page 50/504
# Processing page 51/504
# Processing page 52/504
# Processing page 53/504
# Processing page 54/504
# Processing page 55/504
# Processing page 56/504
# Processing page 57/504
# Processing page 58/504
# Processing page 59/504
# Processing page 60/504
# Processing page 61/504
# Processing page 62/504
# Processing page 63/504
# Processing page 64/504
# Processing page 65/504
# Processing page 66/504
# Processing page 67/504
# Processing page 68/504
# Processing page 69/504
# Processing page 70/504
# Processing page 71/504
# Processing page 72/504
# Processing page 73/504
# Processing page 74/504
# Processing page 75/504
# Processing page 76/504
# Processing page 77/504
# Processing page 78/504
# Processing page 79/504
# Processing page 80/504
# Processing page 81/504
# Processing page 82/504
# Processing page 83/504
# Processing page 84/504
# Processing page 85/504
# Processing page 86/504
# Processing page 87/504
# Processing page 88/504
# Processing page 89/504
# Processing page 90/504
# Processing page 91/504
# Processing page 92/504
# Processing page 93/504
# Processing page 94/504
# Processing page 95/504
# Processing page 96/504
# Processing page 97/504
# Processing page 98/504
# Processing page 99/504
# Processing page 100/504
# Processing page 101/504
# Processing page 102/504
# Processing page 103/504
# Processing page 104/504
# Processing page 105/504
# Processing page 106/504
# Processing page 107/504
# Processing page 108/504
# Processing page 109/504
# Processing page 110/504
# Processing page 111/504
# Processing page 112/504
# Processing page 113/504
# Processing page 114/504
# Processing page 115/504
# Processing page 116/504
# Processing page 117/504
# Processing page 118/504
# Processing page 119/504
# Processing page 120/504
# Processing page 121/504
# Processing page 122/504
# Processing page 123/504
# Processing page 124/504
# Processing page 125/504
# Processing page 126/504
# Processing page 127/504
# Processing page 128/504
# Processing page 129/504
# Processing page 130/504
# Processing page 131/504
# Processing page 132/504
# Processing page 133/504
# Processing page 134/504
# Processing page 135/504
# Processing page 136/504
# Processing page 137/504
# Processing page 138/504
# Processing page 139/504
# Processing page 140/504
# Processing page 141/504
# Processing page 142/504
# Processing page 143/504
# Processing page 144/504
# Processing page 145/504
# Processing page 146/504
# Processing page 147/504
# Processing page 148/504
# Processing page 149/504
# Processing page 150/504
# Processing page 151/504
# Processing page 152/504
# Processing page 153/504
# Processing page 154/504
# Processing page 155/504
# Processing page 156/504
# Processing page 157/504
# Processing page 158/504
# Processing page 159/504
# Processing page 160/504
# Processing page 161/504
# Processing page 162/504
# Processing page 163/504
# Processing page 164/504
# Processing page 165/504
# Processing page 166/504
# Processing page 167/504
# Processing page 168/504
# Processing page 169/504
# Processing page 170/504
# Processing page 171/504
# Processing page 172/504
# Processing page 173/504
# Processing page 174/504
# Processing page 175/504
# Processing page 176/504
# Processing page 177/504
# Processing page 178/504
# Processing page 179/504
# Processing page 180/504
# Processing page 181/504
# Processing page 182/504
# Processing page 183/504
# Processing page 184/504
# Processing page 185/504
# Processing page 186/504
# Processing page 187/504
# Processing page 188/504
# Processing page 189/504
# Processing page 190/504
# Processing page 191/504
# Processing page 192/504
# Processing page 193/504
# Processing page 194/504
# Processing page 195/504
# Processing page 196/504
# Processing page 197/504
# Processing page 198/504
# Processing page 199/504
# Processing page 200/504
# Processing page 201/504
# Processing page 202/504
# Processing page 203/504
# Processing page 204/504
# Processing page 205/504
# Processing page 206/504
# Processing page 207/504
# Processing page 208/504
# Processing page 209/504
# Processing page 210/504
# Processing page 211/504
# Processing page 212/504
# Processing page 213/504
# Processing page 214/504
# Processing page 215/504
# Processing page 216/504
# Processing page 217/504
# Processing page 218/504
# Processing page 219/504
# Processing page 220/504
# Processing page 221/504
# Processing page 222/504
# Processing page 223/504
# Processing page 224/504
# Processing page 225/504
# Processing page 226/504
# Processing page 227/504
# Processing page 228/504
# Processing page 229/504
# Processing page 230/504
# Processing page 231/504
# Processing page 232/504
# Processing page 233/504
# Processing page 234/504
# Processing page 235/504
# Processing page 236/504
# Processing page 237/504
# Processing page 238/504
# Processing page 239/504
# Processing page 240/504
# Processing page 241/504
# Processing page 242/504
# Processing page 243/504
# Processing page 244/504
# Processing page 245/504
# Processing page 246/504
# Processing page 247/504
# Processing page 248/504
# Processing page 249/504
# Processing page 250/504
# Processing page 251/504
# Processing page 252/504
# Processing page 253/504
# Processing page 254/504
# Processing page 255/504
# Processing page 256/504
# Processing page 257/504
# Processing page 258/504
# Processing page 259/504
# Processing page 260/504
# Processing page 261/504
# Processing page 262/504
# Processing page 263/504
# Processing page 264/504
# Processing page 265/504
# Processing page 266/504
# Processing page 267/504
# Processing page 268/504
# Processing page 269/504
# Processing page 270/504
# Processing page 271/504
# Processing page 272/504
# Processing page 273/504
# Processing page 274/504
# Processing page 275/504
# Processing page 276/504
# Processing page 277/504
# Processing page 278/504
# Processing page 279/504
# Processing page 280/504
# Processing page 281/504
# Processing page 282/504
# Processing page 283/504
# Processing page 284/504
# Processing page 285/504
# Processing page 286/504
# Processing page 287/504
# Processing page 288/504
# Processing page 289/504
# Processing page 290/504
# Processing page 291/504
# Processing page 292/504
# Processing page 293/504
# Processing page 294/504
# Processing page 295/504
# Processing page 296/504
# Processing page 297/504
# Processing page 298/504
# Processing page 299/504
# Processing page 300/504
# Processing page 301/504
# Processing page 302/504
# Processing page 303/504
# Processing page 304/504
# Processing page 305/504
# Processing page 306/504
# Processing page 307/504
# Processing page 308/504
# Processing page 309/504
# Processing page 310/504
# Processing page 311/504
# Processing page 312/504
# Processing page 313/504
# Processing page 314/504
# Processing page 315/504
# Processing page 316/504
# Processing page 317/504
# Processing page 318/504
# Processing page 319/504
# Processing page 320/504
# Processing page 321/504
# Processing page 322/504
# Processing page 323/504
# Processing page 324/504
# Processing page 325/504
# Processing page 326/504
# Processing page 327/504
# Processing page 328/504
# Processing page 329/504
# Processing page 330/504
# Processing page 331/504
# Processing page 332/504
# Processing page 333/504
# Processing page 334/504
# Processing page 335/504
# Processing page 336/504
# Processing page 337/504
# Processing page 338/504
# Processing page 339/504
# Processing page 340/504
# Processing page 341/504
# Processing page 342/504
# Processing page 343/504
# Processing page 344/504
# Processing page 345/504
# Processing page 346/504
# Processing page 347/504
# Processing page 348/504
# Processing page 349/504
# Processing page 350/504
# Processing page 351/504
# Processing page 352/504
# Processing page 353/504
# Processing page 354/504
# Processing page 355/504
# Processing page 356/504
# Processing page 357/504
# Processing page 358/504
# Processing page 359/504
# Processing page 360/504
# Processing page 361/504
# Processing page 362/504
# Processing page 363/504
# Processing page 364/504
# Processing page 365/504
# Processing page 366/504
# Processing page 367/504
# Processing page 368/504
# Processing page 369/504
# Processing page 370/504
# Processing page 371/504
# Processing page 372/504
# Processing page 373/504
# Processing page 374/504
# Processing page 375/504
# Processing page 376/504
# Processing page 377/504
# Processing page 378/504
# Processing page 379/504
# Processing page 380/504
# Processing page 381/504
# Processing page 382/504
# Processing page 383/504
# Processing page 384/504
# Processing page 385/504
# Processing page 386/504
# Processing page 387/504
# Processing page 388/504
# Processing page 389/504
# Processing page 390/504
# Processing page 391/504
# Processing page 392/504
# Processing page 393/504
# Processing page 394/504
# Processing page 395/504
# Processing page 396/504
# Processing page 397/504
# Processing page 398/504
# Processing page 399/504
# Processing page 400/504
# Processing page 401/504
# Processing page 402/504
# Processing page 403/504
# Processing page 404/504
# Processing page 405/504
# Processing page 406/504
# Processing page 407/504
# Processing page 408/504
# Processing page 409/504
# Processing page 410/504
# Processing page 411/504
# Processing page 412/504
# Processing page 413/504
# Processing page 414/504
# Processing page 415/504
# Processing page 416/504
# Processing page 417/504
# Processing page 418/504
# Processing page 419/504
# Processing page 420/504
# Processing page 421/504
# Processing page 422/504
# Processing page 423/504
# Processing page 424/504
# Processing page 425/504
# Processing page 426/504
# Processing page 427/504
# Processing page 428/504
# Processing page 429/504
# Processing page 430/504
# Processing page 431/504
# Processing page 432/504
# Processing page 433/504
# Processing page 434/504
# Processing page 435/504
# Processing page 436/504
# Processing page 437/504
# Processing page 438/504
# Processing page 439/504
# Processing page 440/504
# Processing page 441/504
# Processing page 442/504
# Processing page 443/504
# Processing page 444/504
# Processing page 445/504
# Processing page 446/504
# Processing page 447/504
# Processing page 448/504
# Processing page 449/504
# Processing page 450/504
# Processing page 451/504
# Processing page 452/504
# Processing page 453/504
# Processing page 454/504
# Processing page 455/504
# Processing page 456/504
# Processing page 457/504
# Processing page 458/504
# Processing page 459/504
# Processing page 460/504
# Processing page 461/504
# Processing page 462/504
# Processing page 463/504
# Processing page 464/504
# Processing page 465/504
# Processing page 466/504
# Processing page 467/504
# Processing page 468/504
# Processing page 469/504
# Processing page 470/504
# Processing page 471/504
# Processing page 472/504
# Processing page 473/504
# Processing page 474/504
# Processing page 475/504
# Processing page 476/504
# Processing page 477/504
# Processing page 478/504
# Processing page 479/504
# Processing page 480/504
# Processing page 481/504
# Processing page 482/504
# Processing page 483/504
# Processing page 484/504
# Processing page 485/504
# Processing page 486/504
# Processing page 487/504
# Processing page 488/504
# Processing page 489/504
# Processing page 490/504
# Processing page 491/504
# Processing page 492/504
# Processing page 493/504
# Processing page 494/504
# Processing page 495/504
# Processing page 496/504
# Processing page 497/504
# Processing page 498/504
# Processing page 499/504
# Processing page 500/504
# Processing page 501/504
# Processing page 502/504
# Processing page 503/504
# Processing page 504/504
# Processing completed. Results saved to /content/drive/MyDrive/out2/

# %%
# !mkdir -p /content/results
